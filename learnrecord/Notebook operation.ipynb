# %%
#
import numpy as np
import matplotlib.pyplot as plt

# %%
# %timeit np.random.randn(10000)
# Out:
# 120 μs ± 945 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%time
data = np.random.randn(1000000)
_ = data.mean(), data.std()
# Out:
# CPU times: user 14.7 ms, sys: 7.79 ms, total: 22.5 ms
# Wall time: 21.8 ms

# %%
# %matplotlib inline
plt.figure(figsize=(8, 4))
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.title("我的第一张 Jupyter 内联图")
plt.show()
# Out:
# /home/mrzhou_learn/ai-engineering-from-scratch-zh/.venv/lib/python3.12/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 25105 (\N{CJK UNIFIED IDEOGRAPH-6211}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/mrzhou_learn/ai-engineering-from-scratch-zh/.venv/lib/python3.12/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/mrzhou_learn/ai-engineering-from-scratch-zh/.venv/lib/python3.12/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 31532 (\N{CJK UNIFIED IDEOGRAPH-7B2C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/mrzhou_learn/ai-engineering-from-scratch-zh/.venv/lib/python3.12/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 19968 (\N{CJK UNIFIED IDEOGRAPH-4E00}) missing from font(s) DejaVu Sans.
# ...
