# %% [markdown]
# # Phase 0-05 Jupyter Notebook 学习笔记
# 这是我用 Markdown 写的笔记标题。

# %%
print("这是固定初始化单元格，所有初始化代码都在这里进行")

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x=10
y=5

plt.rcParams['font.sans-serif'] = ['Noto Sans CJK SC', 'Noto Sans CJK JP', 'DejaVu Sans']
plt.rcParams['axes.unicode_minus'] = False   # 负号正常显示

# %% [markdown]
# 我学会了 Code 和 Markdown

# %%
x+5

# %%
x=x+100
print(x)

# %%
print(y)

# %%
# %timeit [i**2 for i in range(1000)]

# %%
# !dir

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
plt.title("sin(x) 图像")
plt.show()

# %%
from matplotlib import font_manager
names = sorted(set(f.name for f in font_manager.fontManager.ttflist))
print([n for n in names if 'Noto' in n or 'CJK' in n or 'Hei' in n])

# %% [markdown]
# # 神经网络的前向传播
#
# 一个神经元做的事情是：
#
# $$y = \sigma(W x+ b)$$
#
# 其中：
# - $W$ 是权重向量
# - $x$ 是输入向量
# - $b$ 是偏置
# - $\sigma$ 是激活函数，例如 $\sigma(z) = \frac{1}{1 + e^{-z}}$
#
# 梯度下降更新规则：
#
# $$\theta \leftarrow w - \alpha \frac{\partial L}{\partial w}$$

# %%
# 写法 A：纯 Python 列表推导式
# %timeit [i**2 for i in range(100000)]

# %%
# %timeit np.arange(100000)**2
