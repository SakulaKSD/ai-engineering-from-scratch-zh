# %% [markdown]
# # Phase 0-05 Jupyter Notebook 学习笔记
# 这是我用 Markdown 写的笔记标题。

# %%
print("这是代码单元格，我会被真的执行")
# Out:
# 这是代码单元格，我会被真的执行

# %% [markdown]
# 我学会了 Code 和 Markdown

# %%
x=10

# %%
x+5
# Out:
# 15

# %%
x=x+100
print(x)
# Out:
# 110

# %%
print(y)
# Out:
# 5

# %%
y=5

# %%
# %timeit [i**2 for i in range(1000)]
# Out:
# 25.1 μs ± 95.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# !dir
# Out:
# AI\ learn\ notebook.ipynb  Notebook\ operation.ipynb  phase0-05-jupyter.ipynb
# CPUVSGPU.py		   env_list.txt

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
plt.title("sin(x) 图像")
plt.show()
# Out:
# /home/mrzhou_learn/ai-engineering-from-scratch-zh/.venv/lib/python3.12/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/mrzhou_learn/ai-engineering-from-scratch-zh/.venv/lib/python3.12/site-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 20687 (\N{CJK UNIFIED IDEOGRAPH-50CF}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
